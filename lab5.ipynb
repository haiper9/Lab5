# %%
import pandas as pd
import numpy as np

# %% [markdown]
#   Month-Дата преступления (дата)
#   total crimes -общее кол-во преступлений(вещественный)
#   Serious -серьёзных престплений(вещественный)
#   Huge_damage-сильный урон после преступления(вещественный)
#   Ecological-экологичекие преступления(вещественный)
#   Terrorism-террористические преступления(вещественный)
#   Extremism-екстремизм(вещественный)
#   Murder-мародёрство(вещественный)
#   Harm_to_health-вред здоровью(вещественный)
#   Rape-насилия(вещественный)
#   Theft-кражи(вещественный)
#   Vehicle_theft-кражи транспорта(вещественный)
#   Fraud_scam-мошенничество(вещественный)
#   Hooligan-хулиганство(вещественный)
#   Drugs-с участием наркотиков(вещественный)
#   Weapons-с применением оружия(вещественный)

# %%
# 2.1 вывод таблицы
df = pd.read_csv("crime.csv")
df
# Out:
#           month  Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# 0    01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 1    01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 2    01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 3    01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 4    01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
# ..          ...           ...       ...          ...         ...        ...
# 200  01.09.2019      166208.0   38967.0      64283.0      1858.0      122.0
# 201  01.10.2019      199038.0   53319.0      81775.0      2322.0      111.0
# 202  01.11.2019      148104.0   31652.0      49623.0      1581.0      149.0
# 203  01.12.2019      155512.0   38470.0      60742.0      1526.0      164.0
# 204  01.01.2020      159172.0   44134.0      57020.0      1264.0      118.0
#
# ...

# %%
# 2.2вывод первых 5 элементов таблицы
df.head(5)
# Out:
#             Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# month
# 2003-01-01      214587.0   88203.0      20162.0      1216.0      630.0
# 2003-02-01      221928.0   88863.0      20889.0      1701.0      678.0
# 2003-03-01      248452.0  101349.0      24053.0      1817.0      809.0
# 2003-04-01      236299.0   91625.0      19754.0      2449.0      892.0
# 2003-05-01      230931.0   89615.0      17519.0      3530.0      796.0
#
#             Extremism  Murder  Harm_to_health   Rape    Theft  Vehicle_theft  \
# month
# 2003-01-01       13.0  2749.0          5559.0  574.0  81014.0         3549.0
# 2003-02-01        5.0  2444.0          4732.0  515.0  95970.0         3697.0
# 2003-03-01       10.0  2864.0          4851.0  560.0  79420.0         4327.0
# 2003-04-01       10.0  2919.0          4722.0  668.0  95215.0         5345.0
# 2003-05-01       20.0  2713.0          4895.0  688.0  94505.0         6374.0
#
#             Fraud_scam  Hooligan    Drugs  Weapons
# month
# ...

# %%
# 2.3 вывод последних 5 элементов таблицы
df.tail(5)
# Out:
#             Total_crimes  Serious  Huge_damage  Ecological  Terrorism  \
# month
# 2019-09-01      166208.0  38967.0      64283.0      1858.0      122.0
# 2019-10-01      199038.0  53319.0      81775.0      2322.0      111.0
# 2019-11-01      148104.0  31652.0      49623.0      1581.0      149.0
# 2019-12-01      155512.0  38470.0      60742.0      1526.0      164.0
# 2020-01-01      159172.0  44134.0      57020.0      1264.0      118.0
#
#             Extremism  Murder  Harm_to_health   Rape    Theft  Vehicle_theft  \
# month
# 2019-09-01       48.0   555.0          1570.0  306.0  67006.0         1903.0
# 2019-10-01       52.0   668.0          1846.0  223.0  81053.0         2197.0
# 2019-11-01       27.0   622.0          1467.0  246.0  57434.0         1344.0
# 2019-12-01       52.0   534.0          1644.0  134.0  63327.0         1374.0
# 2020-01-01       62.0   723.0          2075.0  296.0  53977.0         1092.0
#
#             Fraud_scam  Hooligan    Drugs  Weapons
# month
# ...

# %%
# 2.4 использовать функцию describe()
df.describe()
# Out:
#         Total_crimes        Serious   Huge_damage   Ecological    Terrorism  \
# count     205.000000     205.000000    205.000000   205.000000   205.000000
# mean   221279.019512   59068.487805  38402.039024  2592.463415   197.839024
# std     51720.759692   20501.515982  20755.286960  1028.101551   245.462645
# min    137657.000000   15755.000000   7424.000000  1216.000000    12.000000
# 25%    180711.000000   42135.000000  21813.000000  1888.000000    57.000000
# 50%    207550.000000   51426.000000  26357.000000  2322.000000   103.000000
# 75%    254352.000000   78407.000000  59282.000000  3034.000000   184.000000
# max    359098.000000  108299.000000  87941.000000  6822.000000  1198.000000
#
#         Extremism       Murder  Harm_to_health         Rape          Theft  \
# count  205.000000   205.000000      205.000000   205.000000     205.000000
# mean    59.473171  1451.400000     3276.024390   463.580488   92647.560976
# ...

# %%
# 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки) всеми известными вам способами
df.iloc[1]['Drugs']
# Out:
# 16839.0

# %%
df['Drugs'].values[1]
# Out:
# 16839.0

# %%
# 2.6 фильтрация строк по диапазону индекса
df[0:10]
# Out:
#             Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# month
# 2003-01-01      214587.0   88203.0      20162.0      1216.0      630.0
# 2003-02-01      221928.0   88863.0      20889.0      1701.0      678.0
# 2003-03-01      248452.0  101349.0      24053.0      1817.0      809.0
# 2003-04-01      236299.0   91625.0      19754.0      2449.0      892.0
# 2003-05-01      230931.0   89615.0      17519.0      3530.0      796.0
# 2003-06-01      249710.0   97514.0      19351.0      3121.0      577.0
# 2003-07-01      225847.0   84698.0      14048.0      2340.0      425.0
# 2003-08-01      222107.0   84597.0      15578.0      2137.0      442.0
# 2003-09-01      240131.0   94677.0      18980.0      2542.0      752.0
# 2003-10-01      245711.0   92437.0      17943.0      1898.0      993.0
#
#             Extremism  Murder  Harm_to_health   Rape     Theft  Vehicle_theft  \
# month
# 2003-01-01       13.0  2749.0          5559.0  574.0   81014.0         3549.0
# ...

# %%
# 2.7 фильтрация набора данных по какому-либо условию
df[(df['Rape'] > 700)& (df['Terrorism'] > 1000)]
# Out:
#             Total_crimes  Serious  Huge_damage  Ecological  Terrorism  \
# month
# 2004-03-01      261288.0  90832.0      23328.0      2189.0     1157.0
# 2004-04-01      239677.0  77428.0      21333.0      2634.0     1198.0
# 2004-10-01      250393.0  78516.0      12349.0      2448.0     1086.0
#
#             Extremism  Murder  Harm_to_health   Rape     Theft  Vehicle_theft  \
# month
# 2004-03-01        9.0  3007.0          5363.0  702.0  104182.0         4839.0
# 2004-04-01        9.0  2742.0          4971.0  723.0  100795.0         5460.0
# 2004-10-01        4.0  2633.0          4895.0  763.0  119447.0         7435.0
#
#             Fraud_scam  Hooligan    Drugs  Weapons
# month
# 2004-03-01     12672.0    2390.0  20197.0   2953.0
# 2004-04-01     10736.0    2302.0  17924.0   2380.0
# 2004-10-01      9362.0    1914.0   9931.0   2018.0

# %%
# 2.8) Удаление строк с пропущенными значениями
df.isnull().sum()
# Out:
# Total_crimes      0
# Serious           0
# Huge_damage       0
# Ecological        0
# Terrorism         0
# Extremism         0
# Murder            0
# Harm_to_health    0
# Rape              0
# Theft             0
# Vehicle_theft     0
# Fraud_scam        0
# Hooligan          0
# Drugs             0
# Weapons           0
# dtype: int64

# %%
df.iloc[0:30, 0:30] = np.nan
df
# Out:
#           month  Total_crimes  Serious  Huge_damage  Ecological  Terrorism  \
# 0           NaN           NaN      NaN          NaN         NaN        NaN
# 1           NaN           NaN      NaN          NaN         NaN        NaN
# 2           NaN           NaN      NaN          NaN         NaN        NaN
# 3           NaN           NaN      NaN          NaN         NaN        NaN
# 4           NaN           NaN      NaN          NaN         NaN        NaN
# ..          ...           ...      ...          ...         ...        ...
# 200  01.09.2019      166208.0  38967.0      64283.0      1858.0      122.0
# 201  01.10.2019      199038.0  53319.0      81775.0      2322.0      111.0
# 202  01.11.2019      148104.0  31652.0      49623.0      1581.0      149.0
# 203  01.12.2019      155512.0  38470.0      60742.0      1526.0      164.0
# 204  01.01.2020      159172.0  44134.0      57020.0      1264.0      118.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Total_crimes      30
# Serious           30
# Huge_damage       30
# Ecological        30
# Terrorism         30
# Extremism         30
# Murder            30
# Harm_to_health    30
# Rape              30
# Theft             30
# Vehicle_theft     30
# Fraud_scam        30
# Hooligan          30
# Drugs             30
# Weapons           30
# dtype: int64

# %%
df = df.dropna(axis=0)
df
# Out:
#             Total_crimes  Serious  Huge_damage  Ecological  Terrorism  \
# month
# 2005-07-01      302965.0  87499.0      16579.0      2802.0      255.0
# 2005-08-01      326263.0  95231.0      18039.0      2688.0      294.0
# 2005-09-01      330848.0  98196.0      20602.0      3432.0      397.0
# 2005-10-01      322364.0  92091.0      16924.0      3170.0      521.0
# 2005-11-01      310280.0  89826.0      17049.0      2711.0      480.0
# ...                  ...      ...          ...         ...        ...
# 2019-09-01      166208.0  38967.0      64283.0      1858.0      122.0
# 2019-10-01      199038.0  53319.0      81775.0      2322.0      111.0
# 2019-11-01      148104.0  31652.0      49623.0      1581.0      149.0
# 2019-12-01      155512.0  38470.0      60742.0      1526.0      164.0
# 2020-01-01      159172.0  44134.0      57020.0      1264.0      118.0
#
#             Extremism  Murder  Harm_to_health    Rape     Theft  \
# month
# ...

# %%
# 2.9) создание нового поля вычисленного на основе значений других полей:
# 2.9.1) через выражение на базе имеющихся колонок
df1=pd.read_csv("crime.csv")
df1['total theft'] = df1['Theft']+df1['Vehicle_theft']
df1
# Out:
#           month  Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# 0    01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 1    01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 2    01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 3    01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 4    01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
# ..          ...           ...       ...          ...         ...        ...
# 200  01.09.2019      166208.0   38967.0      64283.0      1858.0      122.0
# 201  01.10.2019      199038.0   53319.0      81775.0      2322.0      111.0
# 202  01.11.2019      148104.0   31652.0      49623.0      1581.0      149.0
# 203  01.12.2019      155512.0   38470.0      60742.0      1526.0      164.0
# 204  01.01.2020      159172.0   44134.0      57020.0      1264.0      118.0
#
# ...

# %%
# 2.9.2) через DataFrame.apply
df1['total theft'] = df1.apply(lambda row: row['Theft']+row['Vehicle_theft'], axis=1)
df1
# Out:
#           month  Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# 0    01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 1    01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 2    01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 3    01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 4    01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
# ..          ...           ...       ...          ...         ...        ...
# 200  01.09.2019      166208.0   38967.0      64283.0      1858.0      122.0
# 201  01.10.2019      199038.0   53319.0      81775.0      2322.0      111.0
# 202  01.11.2019      148104.0   31652.0      49623.0      1581.0      149.0
# 203  01.12.2019      155512.0   38470.0      60742.0      1526.0      164.0
# 204  01.01.2020      159172.0   44134.0      57020.0      1264.0      118.0
#
# ...

# %%
# 2.9.3) через Series.apply
df1=pd.read_csv("crime.csv")
df1['Total theft'] = (df1['Theft']+df1['Vehicle_theft']).apply(lambda x: max(x, 0))
df1
# Out:
#           month  Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# 0    01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 1    01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 2    01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 3    01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 4    01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
# ..          ...           ...       ...          ...         ...        ...
# 200  01.09.2019      166208.0   38967.0      64283.0      1858.0      122.0
# 201  01.10.2019      199038.0   53319.0      81775.0      2322.0      111.0
# 202  01.11.2019      148104.0   31652.0      49623.0      1581.0      149.0
# 203  01.12.2019      155512.0   38470.0      60742.0      1526.0      164.0
# 204  01.01.2020      159172.0   44134.0      57020.0      1264.0      118.0
#
# ...

# %%
# 2.10) сортировка по какому-либо из полей
# 2.11) вычислить несколько статистик по колонкам.
mean_age = df1['Total_crimes'].mean()
min_age = df1['Total_crimes'].min()
max_age = df1['Total_crimes'].max()
print("Среднее значение: ", mean_age)
print("Минимальное значение: ", min_age)
print("Максимальное значение: ", max_age)
# Out:
# Среднее значение:  221279.0195121951
# Минимальное значение:  137657.0
# Максимальное значение:  359098.0

# %%
# 2.12) .value_counts()
df1['Rape'].value_counts()
# Out:
# 515.0    3
# 312.0    3
# 296.0    3
# 503.0    2
# 343.0    2
#         ..
# 638.0    1
# 675.0    1
# 542.0    1
# 497.0    1
# 134.0    1
# Name: Rape, Length: 176, dtype: int64

# %%
# 2.13) Вывод уникальных значений колонки через .unique()
df1['Drugs'].unique()
# Out:
# array([16006., 16839., 20176., 16614., 14413., 14659., 11146., 12868.,
#        14784., 15052., 13883., 15248., 16477., 18885., 20197., 17924.,
#         7275.,  8190.,  8357., 10707., 11358.,  9931., 10662., 10133.,
#        10135., 13223., 16612., 13667., 14803., 17116., 14206., 16292.,
#        16111., 14528., 14125., 14423., 14091., 16427., 20646., 18178.,
#        18220., 19412., 16962., 19163., 19065., 17356., 16255., 16244.,
#        17799., 19495., 22928., 19606., 20431., 21339., 18234., 20770.,
#        20120., 18635., 16705., 15156., 18745., 20779., 22519., 20225.,
#        19354., 20567., 18962., 19359., 19686., 18539., 16858., 17020.,
#        20242., 21636., 24340., 20637., 18892., 20995., 19588., 21159.,
#        18158., 16621., 16079., 19164., 19840., 22669., 19344., 17565.,
#        19683., 17616., 18515., 17131., 16762., 15210., 17743., 18841.,
#        21153., 18379., 17767., 16363., 18751., 18409., 18205., 15784.,
# ...

# %%
# 2.14) Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит
df1.set_index('month', inplace=True)
df1
# Out:
#             Total_crimes   Serious  Huge_damage  Ecological  Terrorism  \
# month
# 01.01.2003      214587.0   88203.0      20162.0      1216.0      630.0
# 01.02.2003      221928.0   88863.0      20889.0      1701.0      678.0
# 01.03.2003      248452.0  101349.0      24053.0      1817.0      809.0
# 01.04.2003      236299.0   91625.0      19754.0      2449.0      892.0
# 01.05.2003      230931.0   89615.0      17519.0      3530.0      796.0
# ...                  ...       ...          ...         ...        ...
# 01.09.2019      166208.0   38967.0      64283.0      1858.0      122.0
# 01.10.2019      199038.0   53319.0      81775.0      2322.0      111.0
# 01.11.2019      148104.0   31652.0      49623.0      1581.0      149.0
# 01.12.2019      155512.0   38470.0      60742.0      1526.0      164.0
# 01.01.2020      159172.0   44134.0      57020.0      1264.0      118.0
#
#             Extremism  Murder  Harm_to_health   Rape    Theft  Vehicle_theft  \
# month
# ...
